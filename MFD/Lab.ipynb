# %% [markdown]
# <h1>This is the Labratory for Testing MC Simulations and Portfolios</h1>
# <p>Note: this simulation does not account for dividends, at least not yet</p>

# %%
from montecarlo_functions import MonteCarlo
# Out:
# C:\Users\Caleb\anaconda3\envs\Sandbox\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
portfolio_sims = MonteCarlo(7000,
           ['AMZN', 'CEG', 'NFLX', 'QQQI', 'SPYG', 'VXUS', 'VTI'],
           num_sims=10000,
           look_back=10*365,
           max_allocation=40,
           optimize=True,
           method="Sharpe",
           show_plots=False)
# Out:
# [*********************100%***********************]  7 of 7 completed
# ===========================================================================
#                             DATA DIAGNOSTICS
# ===========================================================================
#
# --- PORTFOLIO INPUT STATS ---
#                Mean Daily   Annual Ret   Volatility       Sharpe  Div Yld (Y)  Div Yld (Q)       Max DD
# AMZN              0.0940%       23.69%       31.90%        0.743        0.00%        0.00%      -56.15%
# CEG               0.2262%       57.00%       58.00%        0.983        0.68%        0.21%      -50.70%
# NFLX              0.1309%       32.98%       32.26%        1.022        0.00%        0.00%      -75.95%
# QQQI              0.0705%       17.77%       17.44%        1.019       12.11%        4.05%      -20.00%
# SPYG              0.0892%       22.48%       20.75%        1.083        1.06%        0.29%      -32.67%
# VTI               0.0692%       17.43%       16.45%        1.059        1.61%        0.44%      -35.00%
# VXUS              0.0814%       20.51%       15.25%        1.345        3.24%        0.89%      -35.97%
#
# ===================================
#      PORTFOLIO WEIGHTS
# ===================================
# AMZN  :   0.00%
# CEG   :  10.72%
# NFLX  :  24.61%
# QQQI  :   0.00%
# SPYG  :   0.00%
# VXUS  :  24.67%
# VTI   :  40.00%
#
# ===================================
#      PERFORMANCE METRICS
# ===================================
# Sharpe Ratio:                1.3457
# VaR:                         $-59.17
# CVaR:                        $517.99
# Mean Portfolio Value:        $10318.96
# Std Dev:                     $2258.24
# Expected Total Return:       $3318.96
# Expected Percent Return:     47.41%
# Probability of Profit:       95.46%
