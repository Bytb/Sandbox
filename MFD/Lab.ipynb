# %% [markdown]
# <h1>This is the Labratory for Testing MC Simulations and Portfolios</h1>
# <p>Note: this simulation does not account for dividends, at least not yet</p>

# %%
from montecarlo_functions import MonteCarlo
# Out:
# C:\Users\Caleb\anaconda3\envs\Sandbox\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
portfolio_sims = MonteCarlo(7000,
           ['AMZN', 'CEG', 'NFLX', 'QQQI', 'SPYG', 'VXUS', 'VTI'],
           num_sims=10000,
           look_back=10*365,
           max_allocation=40,
           optimize=True,
           method="CVaR",
           show_plots=False)
# Out:
# [*********************100%***********************]  7 of 7 completed
# ===========================================================================
#                             DATA DIAGNOSTICS
# ===========================================================================
#
# --- PORTFOLIO INPUT STATS ---
#                Mean Daily   Annual Ret   Volatility       Sharpe  Div Yld (Y)  Div Yld (Q)       Max DD
# AMZN              0.1009%       25.43%       31.94%        0.796        0.00%        0.00%      -56.15%
# CEG               0.2280%       57.45%       57.92%        0.992        0.68%        0.21%      -50.70%
# NFLX              0.1379%       34.76%       32.27%        1.077        0.00%        0.00%      -75.95%
# QQQI              0.0742%       18.71%       17.43%        1.073       12.11%        4.05%      -20.00%
# SPYG              0.0960%       24.19%       20.78%        1.164        1.06%        0.29%      -32.67%
# VTI               0.0733%       18.47%       16.46%        1.122        1.61%        0.44%      -35.00%
# VXUS              0.0831%       20.95%       15.24%        1.375        3.24%        0.89%      -35.97%
#
# ===================================
#      PORTFOLIO WEIGHTS
# ===================================
# AMZN  :   2.37%
# CEG   :  40.00%
# NFLX  :  40.00%
# QQQI  :   0.00%
# SPYG  :   0.00%
# VXUS  :   0.00%
# VTI   :  17.63%
#
# ===================================
#      PERFORMANCE METRICS
# ===================================
# Sharpe Ratio:                1.1351
# VaR:                         $479.44
# CVaR:                        $1359.47
# Mean Portfolio Value:        $12627.58
# Std Dev:                     $4710.94
# Expected Total Return:       $5627.58
# Expected Percent Return:     80.39%
# Probability of Profit:       92.43%
