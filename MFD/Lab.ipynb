# %% [markdown]
# <h1>This is the Labratory for Testing MC Simulations and Portfolios</h1>

# %%
from montecarlo_functions import MonteCarlo
# Out:
# C:\Users\Caleb\anaconda3\envs\Sandbox\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
portfolio_sims = MonteCarlo(7000,
           ['AMZN', 'CEG', 'NFLX', 'QQQI', 'SPYG', 'VXUS', 'VTI'],
           num_sims=10000,
           look_back=10*365,
           max_allocation=40,
           optimize=True,
           method="Sharpe",
           show_plots=False)
# Out:
# [*********************100%***********************]  7 of 7 completed
# ==================================================
#            DATA DIAGNOSTICS
# ==================================================
#
# --- RETURN STATS ---
#        Mean Daily Return Annual Return Annual Volatility Sharpe Ratio
# Ticker
# AMZN             0.0939%        23.67%            31.90%        0.742
# CEG              0.2236%        56.33%            58.01%        0.971
# NFLX             0.1307%        32.93%            32.26%        1.021
# QQQI             0.0146%         3.69%            17.94%        0.205
# SPYG             0.0866%        21.81%            20.73%        1.052
# VTI              0.0639%        16.11%            16.48%        0.978
# VXUS             0.0692%        17.44%            15.40%        1.132
# Monte Carlo:   5%|▍         | 5/106 [00:02<01:12,  1.39step/s, optimizing]
# --- DIVIDEND STATS ---
#      Dividend Yield
# AMZN          0.00%
# CEG           2.87%
# NFLX          0.00%
# QQQI         31.01%
# SPYG          9.62%
# VXUS         30.18%
# VTI          15.44%
#
# --- RISK STATS ---
#      Max Drawdown
# AMZN      -56.15%
# CEG       -50.79%
# NFLX      -75.95%
# QQQI      -21.86%
# SPYG      -33.12%
# VXUS      -39.92%
# VTI       -35.00%
# Monte Carlo: 107step [00:29,  3.62step/s, finalizing]
# ===================================
#      PORTFOLIO WEIGHTS
# ===================================
# AMZN  :   0.39%
# CEG   :  13.27%
# NFLX  :  26.42%
# QQQI  :   0.00%
# SPYG  :   0.00%
# VXUS  :  19.92%
# VTI   :  40.00%
#
# ===================================
#      PERFORMANCE METRICS
# ===================================
# Sharpe Ratio:                1.2747
# VaR:                         $80.09
# CVaR:                        $676.60
# Mean Portfolio Value:        $10290.91
# Std Dev:                     $2361.96
# Expected Total Return:       $3290.91
# Expected Percent Return:     47.01%
# Probability of Profit:       94.43%
