# %% [markdown]
# <h1>This is the Labratory for Testing MC Simulations and Portfolios</h1>

# %%
from montecarlo_functions import MonteCarlo
# Out:
# C:\Users\Caleb\anaconda3\envs\Sandbox\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
portfolio_sims = MonteCarlo(7000,
           ['AMZN', 'CEG', 'NFLX', 'QQQI', 'SPYG', 'VXUS', 'VTI'],
           num_sims=10000,
           look_back=10*365,
           max_allocation=40,
           optimize=True,
           method="Sharpe",
           show_plots=False)
# Out:
# [*********************100%***********************]  7 of 7 completed
# ===========================================================================
#                             DATA DIAGNOSTICS
# ===========================================================================
#
# --- PORTFOLIO INPUT STATS ---
#                Mean Daily   Annual Ret   Volatility       Sharpe  Div Yld (Y)  Div Yld (Q)       Max DD
# AMZN              0.0940%       23.70%       31.90%        0.743        0.00%        0.00%      -56.15%
# CEG               0.2234%       56.30%       58.01%        0.971        0.67%        0.20%      -50.79%
# NFLX              0.1309%       32.98%       32.26%        1.022        0.00%        0.00%      -75.95%
# QQQI              0.0147%        3.70%       17.94%        0.206       10.34%        3.45%      -21.86%
# SPYG              0.0867%       21.85%       20.73%        1.054        1.00%        0.28%      -33.12%
# VTI               0.0640%       16.12%       16.48%        0.978        1.48%        0.41%      -35.00%
# VXUS              0.0692%       17.45%       15.40%        1.133        2.76%        0.76%      -39.92%
#
# ===================================
#      PORTFOLIO WEIGHTS
# ===================================
# AMZN  :   0.00%
# CEG   :  12.53%
# NFLX  :  28.99%
# QQQI  :   0.00%
# SPYG  :   0.00%
# VXUS  :  18.48%
# VTI   :  40.00%
#
# ===================================
#      PERFORMANCE METRICS
# ===================================
# Sharpe Ratio:                1.2545
# VaR:                         $86.46
# CVaR:                        $665.71
# Mean Portfolio Value:        $10281.61
# Std Dev:                     $2392.61
# Expected Total Return:       $3281.61
# Expected Percent Return:     46.88%
# Probability of Profit:       94.44%
